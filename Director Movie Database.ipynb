# %% [markdown]
# # James Cameron's all Directed Movies

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://en.wikipedia.org/wiki/James_Cameron")
bsObj = BeautifulSoup(html.read())

directed_feature = bsObj.find("table",{"class":"wikitable"})
print(directed_feature.prettify())
# Out:
# <table class="wikitable">
#  <caption>
#   Directed features
#  </caption>
#  <tbody>
#   <tr>
#    <th>
#     Year
#    </th>
#    <th>
#     Title
#    </th>
#    <th>
#     Distributor
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1982
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Piranha_II:_The_Spawning" title="Piranha II: The Spawning">
#       Piranha II: The Spawning
#      </a>
#     </i>
#    </td>
#    <td>
#     Saturn International Pictures /
#     <a href="/wiki/Columbia_Pictures" title="Columbia Pictures">
#      Columbia Pictures
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1984
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/The_Terminator" title="The Terminator">
#       The Terminator
#      </a>
#     </i>
#    </td>
#    <td>
#     <a href="/wiki/Orion_Pictures" title="Orion Pictures">
#      Orion Pictures
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1986
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Aliens_(film)" title="Aliens (film)">
#       Aliens
#      </a>
#     </i>
#    </td>
#    <td rowspan="2">
#     <a class="mw-redirect" href="/wiki/20th_Century_Fox" title="20th Century Fox">
#      20th Century Fox
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1989
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/The_Abyss" title="The Abyss">
#       The Abyss
#      </a>
#     </i>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1991
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Terminator_2:_Judgment_Day" title="Terminator 2: Judgment Day">
#       Terminator 2: Judgment Day
#      </a>
#     </i>
#    </td>
#    <td>
#     <a href="/wiki/TriStar_Pictures" title="TriStar Pictures">
#      TriStar Pictures
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1994
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/True_Lies" title="True Lies">
#       True Lies
#      </a>
#     </i>
#    </td>
#    <td>
#     20th Century Fox /
#     <a href="/wiki/Universal_Pictures" title="Universal Pictures">
#      Universal Pictures
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1997
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Titanic_(1997_film)" title="Titanic (1997 film)">
#       Titanic
#      </a>
#     </i>
#    </td>
#    <td>
#     <a href="/wiki/Paramount_Pictures" title="Paramount Pictures">
#      Paramount Pictures
#     </a>
#     / 20th Century Fox
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2003
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Ghosts_of_the_Abyss" title="Ghosts of the Abyss">
#       Ghosts of the Abyss
#      </a>
#     </i>
#    </td>
#    <td rowspan="2">
#     <a href="/wiki/Walt_Disney_Pictures" title="Walt Disney Pictures">
#      Walt Disney Pictures
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2005
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Aliens_of_the_Deep" title="Aliens of the Deep">
#       Aliens of the Deep
#      </a>
#     </i>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2009
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Avatar_(2009_film)" title="Avatar (2009 film)">
#       Avatar
#      </a>
#     </i>
#    </td>
#    <td>
#     20th Century Fox
#    </td>
#   </tr>
#   <tr>
#    <td align="left" scope="row" style="background:#FFFFCC;">
#     2022
#     <img alt="Films that have not yet been released" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Avatar:_The_Way_of_Water" title="Avatar: The Way of Water">
#       Avatar: The Way of Water
#      </a>
#     </i>
#    </td>
#    <td rowspan="3">
#     20th Century Studios
#    </td>
#   </tr>
#   <tr>
#    <td align="left" scope="row" style="background:#FFFFCC;">
#     2024
#     <img alt="Films that have not yet been released" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Avatar_3" title="Avatar 3">
#       Avatar 3
#      </a>
#     </i>
#    </td>
#   </tr>
#   <tr>
#    <td align="left" scope="row" style="background:#FFFFCC;">
#     2026
#     <img alt="Films that have not yet been released" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
#    </td>
#    <td>
#     <i>
#      <a href="/wiki/Avatar_4" title="Avatar 4">
#       Avatar 4
#      </a>
#     </i>
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://en.wikipedia.org/wiki/James_Cameron")
bsObj = BeautifulSoup(html.read())

directed_feature = bsObj.find("table",{"class":"wikitable"})

all_rows = directed_feature.findAll("tr")

print(all_rows)
# Out:
# [<tr>
# <th>Year
# </th>
# <th>Title
# </th>
# <th>Distributor
# </th></tr>, <tr>
# <td>1982
# </td>
# <td><i><a href="/wiki/Piranha_II:_The_Spawning" title="Piranha II: The Spawning">Piranha II: The Spawning</a></i>
# </td>
# <td>Saturn International Pictures / <a href="/wiki/Columbia_Pictures" title="Columbia Pictures">Columbia Pictures</a>
# </td></tr>, <tr>
# <td>1984
# </td>
# <td><i><a href="/wiki/The_Terminator" title="The Terminator">The Terminator</a></i>
# </td>
# <td><a href="/wiki/Orion_Pictures" title="Orion Pictures">Orion Pictures</a>
# </td></tr>, <tr>
# <td>1986
# </td>
# <td><i><a href="/wiki/Aliens_(film)" title="Aliens (film)">Aliens</a></i>
# </td>
# <td rowspan="2"><a class="mw-redirect" href="/wiki/20th_Century_Fox" title="20th Century Fox">20th Century Fox</a>
# </td></tr>, <tr>
# <td>1989
# </td>
# <td><i><a href="/wiki/The_Abyss" title="The Abyss">The Abyss</a></i>
# </td></tr>, <tr>
# <td>1991
# </td>
# <td><i><a href="/wiki/Terminator_2:_Judgment_Day" title="Terminator 2: Judgment Day">Terminator 2: Judgment Day</a></i>
# </td>
# <td><a href="/wiki/TriStar_Pictures" title="TriStar Pictures">TriStar Pictures</a>
# </td></tr>, <tr>
# <td>1994
# </td>
# <td><i><a href="/wiki/True_Lies" title="True Lies">True Lies</a></i>
# </td>
# <td>20th Century Fox / <a href="/wiki/Universal_Pictures" title="Universal Pictures">Universal Pictures</a>
# </td></tr>, <tr>
# <td>1997
# </td>
# <td><i><a href="/wiki/Titanic_(1997_film)" title="Titanic (1997 film)">Titanic</a></i>
# </td>
# <td><a href="/wiki/Paramount_Pictures" title="Paramount Pictures">Paramount Pictures</a> / 20th Century Fox
# </td></tr>, <tr>
# <td>2003
# </td>
# <td><i><a href="/wiki/Ghosts_of_the_Abyss" title="Ghosts of the Abyss">Ghosts of the Abyss</a></i>
# </td>
# <td rowspan="2"><a href="/wiki/Walt_Disney_Pictures" title="Walt Disney Pictures">Walt Disney Pictures</a>
# </td></tr>, <tr>
# <td>2005
# </td>
# <td><i><a href="/wiki/Aliens_of_the_Deep" title="Aliens of the Deep">Aliens of the Deep</a></i>
# </td></tr>, <tr>
# <td>2009
# </td>
# <td><i><a href="/wiki/Avatar_(2009_film)" title="Avatar (2009 film)">Avatar</a></i>
# </td>
# <td>20th Century Fox
# </td></tr>, <tr>
# <td align="left" scope="row" style="background:#FFFFCC;">2022<img alt="Films that have not yet been released" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
# </td>
# <td><i><a href="/wiki/Avatar:_The_Way_of_Water" title="Avatar: The Way of Water">Avatar: The Way of Water</a></i>
# </td>
# <td rowspan="3">20th Century Studios
# </td></tr>, <tr>
# <td align="left" scope="row" style="background:#FFFFCC;">2024<img alt="Films that have not yet been released" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
# </td>
# <td><i><a href="/wiki/Avatar_3" title="Avatar 3">Avatar 3</a></i>
# </td></tr>, <tr>
# <td align="left" scope="row" style="background:#FFFFCC;">2026<img alt="Films that have not yet been released" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
# </td>
# <td><i><a href="/wiki/Avatar_4" title="Avatar 4">Avatar 4</a></i>
# </td></tr>]

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://en.wikipedia.org/wiki/James_Cameron")
bsObj = BeautifulSoup(html.read())

directed_feature = bsObj.find("table",{"class":"wikitable"})

all_rows = directed_feature.findAll("tr")

count = -1
column_names = list()
years = list()
titles = list()
distributors = list()

for row in all_rows:
    if count==-1:
        for th_tag in row.findAll('th'):
            column_names.append(th_tag.get_text().strip())
    else:
        l = row.findAll('td')
        years.append(l[0].get_text().strip())
        titles.append(l[1].get_text().strip())
        if len(l)==3:
            distributors.append(l[2].get_text().strip())
        else:
            distributors.append(distributors[count-1])
    count = count + 1
    
print(column_names)
print(years)
print(titles)
print(distributors)
# Out:
# ['Year', 'Title', 'Distributor']
# ['1982', '1984', '1986', '1989', '1991', '1994', '1997', '2003', '2005', '2009', '2022', '2024', '2026']
# ['Piranha II: The Spawning', 'The Terminator', 'Aliens', 'The Abyss', 'Terminator 2: Judgment Day', 'True Lies', 'Titanic', 'Ghosts of the Abyss', 'Aliens of the Deep', 'Avatar', 'Avatar: The Way of Water', 'Avatar 3', 'Avatar 4']
# ['Saturn International Pictures / Columbia Pictures', 'Orion Pictures', '20th Century Fox', '20th Century Fox', 'TriStar Pictures', '20th Century Fox / Universal Pictures', 'Paramount Pictures / 20th Century Fox', 'Walt Disney Pictures', 'Walt Disney Pictures', '20th Century Fox', '20th Century Studios', '20th Century Studios', '20th Century Studios']

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

html = urlopen("https://en.wikipedia.org/wiki/James_Cameron")
bsObj = BeautifulSoup(html.read())

directed_feature = bsObj.find("table",{"class":"wikitable"})

all_rows = directed_feature.findAll("tr")

count = -1
column_names = list()
years = list()
titles = list()
distributors = list()

for row in all_rows:
    if count==-1:
        for th_tag in row.findAll('th'):
            column_names.append(th_tag.get_text().strip())
    else:
        l = row.findAll('td')
        years.append(l[0].get_text().strip())
        titles.append(l[1].get_text().strip())
        if len(l)==3:
            distributors.append(l[2].get_text().strip())
        else:
            distributors.append(distributors[count-1])
    count = count + 1
    
df = pd.DataFrame({
    'Year' : years,
    'Title' : titles,
    'Distributor' : distributors
},  columns = column_names)

df
# Out:
#     Year                       Title  \
# 0   1982    Piranha II: The Spawning
# 1   1984              The Terminator
# 2   1986                      Aliens
# 3   1989                   The Abyss
# 4   1991  Terminator 2: Judgment Day
# 5   1994                   True Lies
# 6   1997                     Titanic
# 7   2003         Ghosts of the Abyss
# 8   2005          Aliens of the Deep
# 9   2009                      Avatar
# 10  2022    Avatar: The Way of Water
# 11  2024                    Avatar 3
# 12  2026                    Avatar 4
#
#                                           Distributor
# 0   Saturn International Pictures / Columbia Pictures
# 1                                      Orion Pictures
# 2                                    20th Century Fox
# 3                                    20th Century Fox
# 4                                    TriStar Pictures
# 5               20th Century Fox / Universal Pictures
# 6               Paramount Pictures / 20th Century Fox
# 7                                Walt Disney Pictures
# 8                                Walt Disney Pictures
# 9                                    20th Century Fox
# 10                               20th Century Studios
# 11                               20th Century Studios
# 12                               20th Century Studios

# %% [markdown]
# # Any Director's all Directed Movies

# %%
director_name = input()
print(director_name)
print(director_name.replace(" ","_"))
print(director_name)
director_name = director_name.replace(" ","_")
print(director_name)
# Out:
# James Cameron
# James Cameron
# James_Cameron
# James Cameron
# James_Cameron

# %%
import re
s = "wikitable hdfgs"
if re.match("^(wikitable)$",s):
    print("matched")
else:
    print("not matched")
# Out:
# not matched

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import re

url = "https://en.wikipedia.org/wiki/"
director_name = input("Enter a director's name : ")
director_name = director_name.replace(" ","_")


html = urlopen(url+director_name)
bsObj = BeautifulSoup(html.read())


directed_feature = bsObj.find("caption").find_next_sibling()

all_rows = directed_feature.findAll("tr")

count = -1
column_names = list()
years = list()
titles = list()
distributors = list()

for row in all_rows:
    if count==-1:
        for th_tag in row.findAll('th'):
            column_names.append(th_tag.get_text().strip())
    else:
        l = row.findAll('td')

        if len(l)==3:
            years.append(l[0].get_text().strip())

            titles.append(l[1].get_text().strip())
            distributors.append(l[2].get_text().strip())

        if len(l)== 1:
            titles.append(l[0].get_text().strip())
            years.append(years[count-1])
            distributors.append(distributors[count-1])

        if len(l)==2:
            italic_list = l[0].findAll("i")
            if len(italic_list) == 0:
                years.append(l[0].get_text().strip())
                titles.append(l[1].get_text().strip())
                distributors.append(distributors[count-1])
            else:
                titles.append(l[0].get_text().strip())
                distributors.append(l[1].get_text().strip())
                years.append(years[count-1])

    count = count + 1

df = pd.DataFrame({
    'Year' : years,
    'Title' : titles,
    'Distributor' : distributors
},  columns = column_names)

df
# Out:
# Enter a director's name : Steven Spielberg
#     Year                                              Title  \
# 0   1971                                               Duel
# 1   1974                              The Sugarland Express
# 2   1975                                               Jaws
# 3   1977                 Close Encounters of the Third Kind
# 4   1979                                               1941
# 5   1981                            Raiders of the Lost Ark
# 6   1982                         E.T. the Extra-Terrestrial
# 7   1984               Indiana Jones and the Temple of Doom
# 8   1985                                   The Color Purple
# 9   1987                                  Empire of the Sun
# 10  1989                                             Always
# 11  1989                 Indiana Jones and the Last Crusade
# 12  1991                                               Hook
# 13  1993                                      Jurassic Park
# 14  1993                                   Schindler's List
# 15  1997                      The Lost World: Jurassic Park
# 16  1997                                            Amistad
# 17  1998                                Saving Private Ryan
# 18  2001                       A.I. Artificial Intelligence
# 19  2002                                    Minority Report
# 20  2002                                Catch Me If You Can
# 21  2004                                       The Terminal
# 22  2005                                  War of the Worlds
# 23  2005                                             Munich
# 24  2008  Indiana Jones and the Kingdom of the Crystal S...
# 25  2011                           The Adventures of Tintin
# 26  2011                                          War Horse
# 27  2012                                            Lincoln
# 28  2015                                    Bridge of Spies
# 29  2016                                            The BFG
# 30  2017                                           The Post
# 31  2018                                   Ready Player One
# 32  2021                                    West Side Story
# 33  2022                                      The Fabelmans
#
#                                           Distributor
# 0                                  Universal Pictures
# 1                                  Universal Pictures
# 2                                  Universal Pictures
# 3                                   Columbia Pictures
# 4              Universal Pictures / Columbia Pictures
# 5                                  Paramount Pictures
# 6                                  Universal Pictures
# 7                                  Paramount Pictures
# 8                                        Warner Bros.
# 9                                        Warner Bros.
# 10                                 Universal Pictures
# 11                                 Paramount Pictures
# 12                                   TriStar Pictures
# 13                                 Universal Pictures
# 14                                 Universal Pictures
# 15                                 Universal Pictures
# 16                                DreamWorks Pictures
# 17           DreamWorks Pictures / Paramount Pictures
# 18        Warner Bros. Pictures / DreamWorks Pictures
# 19             20th Century Fox / DreamWorks Pictures
# 20                                DreamWorks Pictures
# 21                                DreamWorks Pictures
# 22           Paramount Pictures / DreamWorks Pictures
# 23           Universal Pictures / DreamWorks Pictures
# 24                                 Paramount Pictures
# 25                 Paramount Pictures / Sony Pictures
# 26                Walt Disney Studios Motion Pictures
# 27  Walt Disney Studios Motion Pictures / 20th Cen...
# 28  Walt Disney Studios Motion Pictures / 20th Cen...
# 29                Walt Disney Studios Motion Pictures
# 30                                   20th Century Fox
# 31                              Warner Bros. Pictures
# 32                               20th Century Studios
# 33                                 Universal Pictures
